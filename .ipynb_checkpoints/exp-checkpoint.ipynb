# %%
import os
import nibabel as nib
from tqdm import tqdm

# %%
seg_path = 'data/segmentations/33355.nii'
mask = nib.load(seg_path)
mask = mask.get_fdata()
mask.shape
# for filename in tqdm(os.listdir(seg_path)):
#     ex_path = os.path.join(seg_path, filename)
#     mask = nib.load(ex_path)
#     mask = mask.get_fdata()
#     mask = mask[:, ::-1, ::-1].transpose(1, 0 , 2)
#     print(mask)
#     break
# Out:
# (512, 512, 246)

# %%
import pandas as pd
df = pd.read_parquet('data/train_dicom_tags.parquet')

# %%
len(df)
# Out:
# 1510373

# %%
df.head()
# Out:
#    BitsAllocated  BitsStored  Columns ContentDate    ContentTime  \
# 0             16          16      512    20230722  003306.881589
# 1             16          16      512    20230722  003303.279137
# 2             16          16      512    20230722  003343.090736
# 3             16          16      512    20230722  003252.960345
# 4             16          16      512    20230722  003155.059398
#
#                                  FrameOfReferenceUID  HighBit  \
# 0  1.2.826.0.1.3680043.8.498.28466454913303094199...       15
# 1  1.2.826.0.1.3680043.8.498.28466454913303094199...       15
# 2  1.2.826.0.1.3680043.8.498.28466454913303094199...       15
# 3  1.2.826.0.1.3680043.8.498.28466454913303094199...       15
# 4  1.2.826.0.1.3680043.8.498.28466454913303094199...       15
#
#                              ImageOrientationPatient  \
# 0  [1.00000, 0.00000, 0.00000, 0.00000, 1.00000, ...
# 1  [1.00000, 0.00000, 0.00000, 0.00000, 1.00000, ...
# ...

# %%
for idx in tqdm(range(len(df))):
    path = df.loc[idx, 'path']
    if '33355' in path:
        print(path)
# Out:
#  86%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                 | 1302849/1510373 [00:11<00:01, 111603.09it/s]
# train_images/16682/33355/30.dcm
# train_images/16682/33355/161.dcm
# train_images/16682/33355/6.dcm
# train_images/16682/33355/109.dcm
# train_images/16682/33355/201.dcm
# train_images/16682/33355/214.dcm
# train_images/16682/33355/37.dcm
# train_images/16682/33355/8.dcm
# train_images/16682/33355/56.dcm
# train_images/16682/33355/105.dcm
# train_images/16682/33355/11.dcm
# train_images/16682/33355/154.dcm
# train_images/16682/33355/106.dcm
# train_images/16682/33355/182.dcm
# train_images/16682/33355/216.dcm
# train_images/16682/33355/204.dcm
# train_images/16682/33355/133.dcm
# train_images/16682/33355/84.dcm
# train_images/16682/33355/121.dcm
# train_images/16682/33355/136.dcm
# train_images/16682/33355/221.dcm
# train_images/16682/33355/213.dcm
# train_images/16682/33355/244.dcm
# ...

# %%
len(os.listdir('data/train_images/16682/33355'))
# Out:
# 246
